# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install matplotlib
# !pip install numpy

# %%
import cv2

img_path = r"C:\Users\Mohan\Desktop\SoothSayerAnalytics\Open_CV\002. Reading_and_writing_images\images\giraffe-Kenya.png"

image = cv2.imread(img_path)
print(image)
# Out:
# [[[237 197 135]
#   [240 199 137]
#   [240 199 137]
#   ...
#   [225 183 119]
#   [225 183 119]
#   [225 183 119]]
#
#  [[231 191 129]
#   [228 187 126]
#   [228 187 126]
#   ...
#   [228 185 122]
#   [228 185 122]
#   [228 185 122]]
#
#  [[241 200 138]
#   [229 188 127]
#   [229 188 127]
#   ...
#   [225 182 121]
#   [225 183 119]
#   [225 183 119]]
#
#  ...
#
#  [[120 188 223]
#   [119 187 222]
#   [113 181 216]
#   ...
#   [ 61  90 131]
#   [ 77 104 145]
#   [ 87 114 155]]
#
#  [[123 191 225]
#   [130 198 232]
#   [124 192 226]
#   ...
#   [ 53  85 125]
#   [ 72 102 143]
#   [ 87 117 158]]
#
#  [[110 178 212]
#   [123 191 225]
#   [117 185 219]
#   ...
#   [ 49  81 122]
#   [ 69 101 141]
#   [ 87 118 159]]]

# %%
image = cv2.imread("../images/giraffe-Kenya.png")

# %%
cv2.imshow("Image window", image)

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# %%
plt.imshow(image_rgb)

# %%
lower_white = np.array([0,0,190])
upper_white = np.array([30,80,255])

# %%
mask = cv2.inRange(image_hsv, lower_white, upper_white)

# %%
plt.imshow(mask)

# %%
black_hsv = np.uint8([[[120, 255, 0]]])
black_bgr = cv2.cvtColor(black_hsv, cv2.COLOR_HSV2BGR)[0][0]

# %%
image_result = image.copy()
image_result[mask>0] = black_bgr

# %%
image_result_rgb = cv2.cvtColor(image_result, cv2.COLOR_BGR2RGB)

# %%
# PLOT

fig, axs = plt.subplots(1,3, figsize=(12,6))

axs[0].imshow(image_rgb)
axs[0].set_title("Original Image")
axs[0].axis('off')

axs[1].imshow(mask)
axs[1].set_title("Binary Mask")
axs[1].axis('off')


axs[2].imshow(image_result_rgb)
axs[2].set_title("Output Image")
axs[2].axis('off')

plt.tight_layout()
plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
